# %%
from Tools.statistic import *

# %%
root_dir = "__RESULTS__/reliability/40-60/gangjin.down"


if __name__ == "__main__":
    (
        run_cnt,
        cov_mean,
        cov_std,
        corner_mean,
        corner_std,
        total_mean,
        total_std,
        corner_sec_mean,
        corner_sec_std,
        ga_sec_mean,
        ga_sec_std,
    ) = calcStats(root_dir)

    print(f"total runs: {run_cnt}")
    print(f"[gen=100] coverage mean ± std: {cov_mean:.4f} ± {cov_std:.4f}")
    print(f"[final] corner sensors mean ± std: {corner_mean:.2f} ± {corner_std:.2f}")
    print(f"[final] total sensors mean ± std: {total_mean:.2f} ± {total_std:.2f}")
    print(f"[time] corner mean ± std (sec): {corner_sec_mean:.3f} ± {corner_sec_std:.3f}")
    print(f"[time] GA mean ± std (sec): {ga_sec_mean:.3f} ± {ga_sec_std:.3f}")
# Out:
# total runs: 10
# [gen=100] coverage mean ± std: 90.9445 ± 0.5198
# [final] corner sensors mean ± std: 4.00 ± 0.00
# [final] total sensors mean ± std: 11.80 ± 0.40
# [time] corner mean ± std (sec): 0.000 ± 0.000
# [time] GA mean ± std (sec): 174.154 ± 4.436

# %%
from Tools.trend import plotSensorsAvgTrend

root_dir = "__RESULTS__/reliability"
map_name = "gangjin.full"


info = plotSensorsAvgTrend(root_dir=root_dir, map_name=map_name, show_std=True)
{b: (d["runs"], d["gens"]) for b, d in info.items()}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 from Tools.trend import plotSensorsAvgTrend
# ----> 4 info = plotSensorsAvgTrend(root_dir=root_dir, map_name=map_name, show_std=True)
#       5 {b: (d["runs"], d["gens"]) for b, d in info.items()}
#
# NameError: name 'map_name' is not defined
