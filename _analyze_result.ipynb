# %%
from Tools.analyzer import Analyzer

# experiment.py는 __RESULTS__/100_rounds/{map_name}/ 에 저장
analyzer = Analyzer(result_root_path="__RESULTS__/10_rounds/gangjin.full", file_path=0)

class Args:
    STEP = 5
    FIGURE_DPI = 100
    FIGURE_SIZE = (10, 3)
args = Args()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 from Tools.analyzer import Analyzer
#       3 # experiment.py는 __RESULTS__/100_rounds/{map_name}/ 에 저장
# ----> 4 analyzer = Analyzer(result_root_path="__RESULTS__/10_rounds/gangjin.full", file_path=2)
#       6 class Args:
#       7     STEP = 5
#
# File <string>:7, in __init__(self, run_data, result_root_path, file_path)
#
# File /workspace/Tools/analyzer.py:76, in Analyzer.__post_init__(self)
#      73 if not root.is_dir():
#      74     raise NotADirectoryError(f"result_root_path must be a directory: {root}")
# ---> 76 json_path = self._resolve_json_path(root, self.file_path)
#      77 with open(json_path, "r", encoding="utf-8") as f:
#      78     self.run = json.load(f)
#
# File /workspace/Tools/analyzer.py:110, in Analyzer._resolve_json_path(self, root, file_path)
#     108         raise FileNotFoundError(f"No .json files under: {root}")
#     109     if file_path < 0 or file_path >= len(files):
# --> 110         raise IndexError(f"index={file_path} out of range (0 ~ {len(files)-1})")
#     111     return files[file_path]
#     113 # 2) path mode
#
# IndexError: index=2 out of range (0 ~ 1)

# %%
analyzer.plot_evolution_trend(
                        xtick_step=args.STEP,
                        include_corners=True,
                        figsize=args.FIGURE_SIZE,
                        dpi=args.FIGURE_DPI,
                        title="Evolution of Results over Generations",
                        #save_path="evolution_trend.png"
                        )

# %%
analyzer.plot_coverage_trend(
    xtick_step=args.STEP,
    title="Coverage Evolution over Generations",
    figsize=args.FIGURE_SIZE,
    dpi=args.FIGURE_DPI,
    #save_path="coverage_trend.png"
)

# %%
analyzer.plot_fitness_trend(
    xtick_step=args.STEP,
    title="Fitness Score over Generations",
    figsize=args.FIGURE_SIZE,
    dpi=args.FIGURE_DPI,
    #save_path="fitness_trend.png"
)

# %%
# 개별 run의 센서 배치도 + 평균 군집거리(m)
analyzer.plot_sensor_placement(grid_m=5, coverage=45)
# Out:
# 평균 군집거리 (가장 가까운 센서까지의 거리 평균): 62.994 m
#   (최소: 43.01 m | 최대: 86.02 m | 표준편차: 12.9 m)
# Saved figure: __RESULTS__/_plots/02-08-07-15/sensor_placement.png
# Total sensors: 20
