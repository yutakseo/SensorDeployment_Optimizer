# %%
from Tools.statistic import *
from Tools.trend import plotSensorsAvgTrend, analyze_change_by_generation
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from .Tools.statistic import *
#       2 from .Tools.trend import plotSensorsAvgTrend, analyze_change_by_generation
#
# ImportError: attempted relative import with no known parent package

# %%
root_dir = "__RESULTS__"
map_name = "seocho.up"

# %%
info = plotSensorsAvgTrend(
    root_dir=f"{root_dir}/reliability/", 
    map_name=map_name, 
    show_std=True,
    dpi=600,
    figsize=(10, 3),
    save_path=f"__RESULTS__/{map_name}_trend.png"
    )
{b: (d["runs"], d["gens"]) for b, d in info.items()}
# Out:
# {'120-140': (10, 100),
#  '100-120': (10, 100),
#  '80-100': (10, 100),
#  '60-80': (10, 100),
#  '40-60': (10, 100)}

# %%
# 모든 초기값(band)이 한번에 수렴하는 유전 세대 (trend 모듈에서 분석)
change_results = analyze_change_by_generation(info, threshold=0.5)
change_results["convergence_gen"]  # 한번에 수렴하는 세대
# Out:
# 변화량 < 0.5 센서일 때 수렴으로 간주.
# **모든 초기값(band)이 한번에 수렴하는 유전 세대: 40세대**
#   40-60: 31세대부터 수렴 (최대 변화량 7.594)
#   60-80: 35세대부터 수렴 (최대 변화량 11.059)
#   80-100: 36세대부터 수렴 (최대 변화량 12.914)
#   120-140: 40세대부터 수렴 (최대 변화량 17.609)
#   100-120: 40세대부터 수렴 (최대 변화량 15.448)
# 40

# %%
root_dir = f"{root_dir}/10_rounds/{map_name}/"
printStats(root_dir)
# Out:
# total runs: 10
# [gen=100] coverage mean ± std: 89.0486 ± 1.2690
# [final] corner sensors mean ± std: 3.00 ± 0.00
# [final] total sensors mean ± std: 16.50 ± 1.57
# [time] corner mean ± std (sec): 0.000 ± 0.000
# [time] GA mean ± std (sec): 42.713 ± 14.945

# %%
# 해당 맵 run들의 평균 군집거리 (가장 가까운 센서까지의 거리 평균, 1그리드=5m)
report_mean_cluster_distance(root_dir, map_name, grid_m=5.0)
# Out:
# [seocho.up] total runs: 10
# [final] 평균 군집거리 mean ± std: 51.365 ± 6.286 m
# [final] 군집거리 min / max: 40.901 / 60.966 m
# {'mean': 51.36503826631299,
#  'std': 6.286351760867495,
#  'min': 40.90122995540586,
#  'max': 60.96632524179492,
#  'n_runs': 10}
